# %% [markdown]
# # **Import Libraries and Dataset**

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('healthcare_sales_dataset.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    product_id   company_id transaction_id       product_name  \
# 0  PMFTMGPWLK  hospital_20     KH9NHAKRFF      Gauze Sponges
# 1  B2L09J6I8B     clinic_3     6XGV4E1D36     Scalpel Blades
# 2  TLJFSQ5K16    clinic_10     OGEAMK0FW0  Disposable Gloves
# 3  3BDN23AHDX   hospital_2     Y68IXY4B8S     Syringes, 50ml
# 4  3BDN23AHDX     clinic_8     3GU73WIOON     Syringes, 50ml
#
#     product_category  sale_amount  quantity_sold  price_per_unit     uom  \
# 0    Medical Devices       463.07             85            5.45   packs
# 1  Surgical Supplies       387.87             12           32.32  pieces
# ...

# %%
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (10000, 15)

# %%
df.dtypes
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_id           object
# company_id           object
# transaction_id       object
# product_name         object
# product_category     object
# sale_amount         float64
# quantity_sold         int64
# price_per_unit      float64
# uom                  object
# address              object
# region               object
# customer_segment     object
# sales_rep_name       object
# date_of_sale         object
# multiple_items        int64
# dtype: object

# %%
df.multiple_items.value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# multiple_items
# 1    7258
# 0    2742
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_id          0
# company_id          0
# transaction_id      0
# product_name        0
# product_category    0
# sale_amount         0
# quantity_sold       0
# price_per_unit      0
# uom                 0
# address             0
# region              0
# customer_segment    0
# sales_rep_name      0
# date_of_sale        0
# multiple_items      0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         sale_amount  quantity_sold  price_per_unit  multiple_items
# count  10000.000000   10000.000000    10000.000000    10000.000000
# mean     248.864717      40.619700        9.648196        0.725800
# std      135.647920      21.914851       13.229527        0.446133
# min       10.060000       1.000000        0.210000        0.000000
# 25%      133.602500      23.000000        3.430000        0.000000
# 50%      231.460000      40.000000        6.000000        1.000000
# 75%      365.560000      57.000000       10.482500        1.000000
# max      499.950000     117.000000      198.420000        1.000000

# %% [markdown]
# # **Transform order data into baskets for analysis**
# Source: https://www.geeksforgeeks.org/implementing-apriori-algorithm-in-python/

# %%
basket_hospital = (df[df['customer_segment'] == "Hospital"]
          .groupby(['transaction_id', 'product_name'])['quantity_sold']
          .sum().unstack().reset_index().fillna(0)
          .set_index('transaction_id'))

basket_clinic = (df[df['customer_segment'] == "Clinic"]
          .groupby(['transaction_id', 'product_name'])['quantity_sold']
          .sum().unstack().reset_index().fillna(0)
          .set_index('transaction_id'))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
basket_hospital.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_name    Adhesive Bandages  Amoxicillin Capsules  Antibiotic Ointment  \
# transaction_id
# 00RH0GOYLY                    0.0                   0.0                  0.0
# 00RI1GPZMY                    0.0                   0.0                  0.0
# 00RRAGO8L7                    0.0                   0.0                  0.0
# 018FBW6JXB                    0.0                   0.0                  0.0
# 02WDOI7VXB                    0.0                  23.0                  0.0
#
# product_name    Aspirin Tablets  Atorvastatin Tablets  Blood Collection Tubes  \
# transaction_id
# ...

# %%
basket_clinic.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_name    Adhesive Bandages  Amoxicillin Capsules  Antibiotic Ointment  \
# transaction_id
# 00FGN3QAL8                    0.0                  45.0                  0.0
# 00IOXHUGW9                    0.0                  43.0                  0.0
# 00JOXHUGX9                    0.0                   0.0                  0.0
# 00RI0GPYMY                   46.0                   0.0                  0.0
# 018OL56TXA                    0.0                   0.0                  0.0
#
# product_name    Aspirin Tablets  Atorvastatin Tablets  Blood Collection Tubes  \
# transaction_id
# ...

# %% [markdown]
# # **Hot encoding the Data**

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
basket_encoded = basket_hospital.map(hot_encode)
basket_hospital = basket_encoded

basket_encoded = basket_clinic.map(hot_encode)
basket_clinic = basket_encoded
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Implement Apriori algorithm to find frequently purchased item baskets**

# %%
frequent_items_hospital = apriori(basket_hospital, min_support=.01, use_colnames=True)
frequent_items_clinic = apriori(basket_clinic, min_support=.005, use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
num_itemsets_hospital = len(frequent_items_hospital)
min_confidence = 0.5

rules_hospital = association_rules(frequent_items_hospital, num_itemsets=num_itemsets_hospital, metric ="lift", min_threshold=min_confidence)
rules_hospital = rules_hospital.sort_values(['confidence', 'lift'], ascending =[False, False])
rules_hospital.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                 antecedents               consequents  antecedent support  \
# 0  (Blood Collection Tubes)          (Syringes, 50ml)            0.054982
# 2  (Diagnostic Test Strips)          (Syringes, 50ml)            0.061624
# 4       (Metformin Tablets)          (Syringes, 50ml)            0.073432
# 3          (Syringes, 50ml)  (Diagnostic Test Strips)            0.129520
# 1          (Syringes, 50ml)  (Blood Collection Tubes)            0.129520
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.129520  0.010332    0.187919  1.450888               1.0
# ...

# %%
num_itemsets_clinic = len(frequent_items_clinic)
min_confidence = 0.5

rules_clinic = association_rules(frequent_items_clinic, num_itemsets=num_itemsets_clinic, metric ="lift", min_threshold=min_confidence)
rules_clinic = rules_clinic.sort_values(['confidence', 'lift'], ascending =[False, False])
rules_clinic.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                  antecedents            consequents  antecedent support  \
# 47       (Disposable Gloves)  (Paracetamol Tablets)            0.056464
# 28  (Blood Collection Tubes)       (Syringes, 50ml)            0.062407
# 8     (Amoxicillin Capsules)       (Syringes, 50ml)            0.069094
# 70          (Sterile Drapes)    (Ibuprofen Tablets)            0.055721
# 68           (IV Tubing Set)       (Syringes, 50ml)            0.063150
#
#     consequent support   support  confidence      lift  representativity  \
# 47            0.069837  0.007058    0.125000  1.789894               1.0
# ...

# %% [markdown]
# # **Recommended Quantities per Bundle**

# %%
top_rule_hospital = rules_hospital.sort_values(by='confidence', ascending=False).iloc[0]

top_antecedent = list(top_rule_hospital['antecedents'])[0]
top_consequent = list(top_rule_hospital['consequents'])[0]

hospital_transactions_df = df[
    (df['customer_segment'] == 'Hospital') &
    (df['product_name'].isin([top_antecedent, top_consequent]))
]

hospital_transactions_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      product_id   company_id transaction_id    product_name  \
# 3    3BDN23AHDX   hospital_2     Y68IXY4B8S  Syringes, 50ml
# 40   3BDN23AHDX   hospital_4     CXEQ8RYU7V  Syringes, 50ml
# 51   3BDN23AHDX   hospital_5     8TIF7LF8IP  Syringes, 50ml
# 64   3BDN23AHDX  hospital_15     BKJUXZTALG  Syringes, 50ml
# 135  3BDN23AHDX   hospital_4     PE9EZ88JLN  Syringes, 50ml
#
#       product_category  sale_amount  quantity_sold  price_per_unit    uom  \
# 3    Surgical Supplies       254.99             17           15.00  boxes
# 40     Medical Devices       351.22             50            7.02  boxes
# ...

# %%
top_rule_clinic = rules_clinic.sort_values(by='confidence', ascending=False).iloc[0]

top_antecedent = list(top_rule_clinic['antecedents'])[0]
top_consequent = list(top_rule_clinic['consequents'])[0]

clinic_transactions_df = df[
    (df['customer_segment'] == 'Clinic') &
    (df['product_name'].isin([top_antecedent, top_consequent]))
]

clinic_transactions_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     product_id company_id transaction_id         product_name  \
# 2   TLJFSQ5K16  clinic_10     OGEAMK0FW0    Disposable Gloves
# 26  0AFGN30KL8  clinic_12     HAKRFF6XGV  Paracetamol Tablets
# 29  0AFGN30KL8   clinic_6     VW295Q1ES5  Paracetamol Tablets
# 66  0AFGN30KL8  clinic_18     HH06FYCXEQ  Paracetamol Tablets
# 99  0AFGN30KL8  clinic_10     A20W97MBJN  Paracetamol Tablets
#
#    product_category  sale_amount  quantity_sold  price_per_unit    uom  \
# 2   Medical Devices       336.95             26           12.96  boxes
# 26  Pharmaceuticals        73.99             37            2.00  packs
# ...

# %%
hospital_bundle_quantities = hospital_transactions_df.groupby(['transaction_id', 'product_name'])['quantity_sold'].sum().unstack()

hospital_average_quantities = hospital_bundle_quantities.mean()

print("Recommended Quantities for the Hospital Bundle:")
for item, qty in hospital_average_quantities.items():
    print(f"{item}: {round(qty)} units")
# Out:
# Recommended Quantities for the Hospital Bundle:
# Blood Collection Tubes: 59 units
# Syringes, 50ml: 50 units
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
clinic_bundle_quantities = clinic_transactions_df.groupby(['transaction_id', 'product_name'])['quantity_sold'].sum().unstack()

clinic_average_quantities = clinic_bundle_quantities.mean()

print("Recommended Quantities for the Clinic Bundle:")
for item, qty in clinic_average_quantities.items():
    print(f"{item}: {round(qty)} units")
# Out:
# Recommended Quantities for the Clinic Bundle:
# Disposable Gloves: 36 units
# Paracetamol Tablets: 27 units
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
